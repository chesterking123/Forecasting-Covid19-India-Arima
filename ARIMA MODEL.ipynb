# %% [markdown]
# # Predicting COVID-19 CASES With Arima Model
# by Deep Contractor

# %% [markdown]
# ![title](https://www.parismou.org/sites/default/files/corona_0.jpeg)

# %%
import IPython
IPython.display.HTML('<div class="flourish-embed flourish-bar-chart-race" data-src="visualisation/1977187" data-url="https://flo.uri.sh/visualisation/1977187/embed"><script src="https://public.flourish.studio/resources/embed.js"></script></div>')
# Out:
# <div class="flourish-embed flourish-bar-chart-race" data-src="visualisation/1977187" data-url="https://flo.uri.sh/visualisation/1977187/embed"><script src="https://public.flourish.studio/resources/embed.js"></script></div>

# %%
import pandas as pd
import numpy as np
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
from time import time
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
df=pd.read_csv('covid_19_india.csv')

# %%
df.tail()
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 1185  1186  21/04/20  5:00 PM            Telengana                       -
# 1186  1187  21/04/20  5:00 PM              Tripura                       -
# 1187  1188  21/04/20  5:00 PM          Uttarakhand                       -
# 1188  1189  21/04/20  5:00 PM        Uttar Pradesh                       -
# 1189  1190  21/04/20  5:00 PM          West Bengal                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 1185                        -    190      23        919
# 1186                        -      1       0          2
# 1187                        -     18       0         46
# 1188                        -    140      20       1294
# 1189                        -     73      12        392

# %% [markdown]
# # PREPROCESSING AND CLEANING

# %%
data = df.copy()
data['Date']=data['Date'].apply(pd.to_datetime)
data.drop(['Sno','Time'],axis=1,inplace=True)

from datetime import date
data_apr = data[data['Date'] >= pd.Timestamp(date(2020,4,19))]

state_cases = data_apr.groupby('State/UnionTerritory')['Confirmed','Deaths','Cured'].max().reset_index()
state_cases['Active'] = state_cases['Confirmed'] - (state_cases['Deaths']+state_cases['Cured'])
state_cases['Death_Rate(per_100)'] = np.round(100*state_cases['Deaths']/state_cases['Confirmed'],2)

# %%
state_cases
# Out:
#            State/UnionTerritory  Confirmed  Deaths  Cured  Active  \
# 0   Andaman and Nicobar Islands         16       0     11       5
# 1                Andhra Pradesh        757      22     96     639
# 2             Arunachal Pradesh          1       0      1       0
# 3                         Assam         35       1     19      15
# 4                         Bihar        114       2     42      70
# 5                    Chandigarh         26       0     13      13
# 6                  Chhattisgarh         36       0     25      11
# 7                         Delhi       2081      47    431    1603
# 8                           Goa          7       0      7       0
# 9                       Gujarat       2066      77    131    1858
# 10                      Haryana        254       3    127     124
# 11             Himachal Pradesh         39       1     16      22
# 12            Jammu and Kashmir        368       5     71     292
# 13                    Jharkhand         46       2      0      44
# 14                    Karnataka        415      17    114     284
# 15                       Kerala        408       3    291     114
# 16                       Ladakh         18       0     14       4
# 17               Madhya Pradesh       1540      76    127    1337
# 18                  Maharashtra       4669     232    572    3865
# 19                      Manipur          2       0      2       0
# 20                    Meghalaya         11       1      0      10
# 21                      Mizoram          1       0      0       1
# 22                     Nagaland          0       0      0       0
# 23                    Nagaland#          0       0      0       0
# 24                       Odisha         74       1     24      49
# 25                   Puducherry          7       0      3       4
# 26                       Punjab        245      16     39     190
# 27                    Rajasthan       1576      25    205    1346
# 28                   Tamil Nadu       1520      17    457    1046
# 29                    Telengana        919      23    190     706
# 30                      Tripura          2       0      1       1
# 31                Uttar Pradesh       1294      20    140    1134
# 32                  Uttarakhand         46       0     18      28
# 33                  West Bengal        392      12     73     307
#
#     Death_Rate(per_100)
# 0                  0.00
# 1                  2.91
# 2                  0.00
# 3                  2.86
# 4                  1.75
# 5                  0.00
# 6                  0.00
# 7                  2.26
# 8                  0.00
# 9                  3.73
# 10                 1.18
# 11                 2.56
# 12                 1.36
# 13                 4.35
# 14                 4.10
# 15                 0.74
# 16                 0.00
# 17                 4.94
# 18                 4.97
# 19                 0.00
# 20                 9.09
# 21                 0.00
# 22                  NaN
# 23                  NaN
# 24                 1.35
# 25                 0.00
# 26                 6.53
# 27                 1.59
# 28                 1.12
# 29                 2.50
# 30                 0.00
# 31                 1.55
# 32                 0.00
# 33                 3.06

# %% [markdown]
# # STATEWISE

# %%
print("** STATE WISE CONFIRMED, DEATH AND CURED CASES of 2019-nCoV**")
state_cases.sort_values('Confirmed', ascending=False).style.background_gradient(cmap='Blues',subset=['Confirmed'])\
.background_gradient(cmap='Reds',subset=['Deaths'])\
.background_gradient(cmap='Greens',subset=['Cured'])\
.background_gradient(cmap='pink',subset=['Active'])\
.background_gradient(cmap='Purples',subset=["Death_Rate(per_100)"])
# Out:
# ** STATE WISE CONFIRMED, DEATH AND CURED CASES of 2019-nCoV**
# <style  type="text/css" >
#     #T_ba82f28c_8f66_11ea_87e9_f82819259437row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row0_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row0_col4 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row1_col1 {
#             background-color:  #81badb;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row1_col2 {
#             background-color:  #fdcab5;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row1_col3 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row1_col4 {
#             background-color:  #c79186;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row1_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row2_col1 {
#             background-color:  #82bbdb;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row2_col2 {
#             background-color:  #fca183;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row2_col3 {
#             background-color:  #ccebc6;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row2_col4 {
#             background-color:  #cea691;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row3_col1 {
#             background-color:  #aacfe5;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row3_col2 {
#             background-color:  #fee3d7;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row3_col3 {
#             background-color:  #a7dba0;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row3_col4 {
#             background-color:  #bd7b7b;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row3_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row4_col1 {
#             background-color:  #add0e6;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row4_col2 {
#             background-color:  #fca285;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row4_col3 {
#             background-color:  #ceecc8;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row4_col4 {
#             background-color:  #bc7a7a;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row4_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row5_col1 {
#             background-color:  #aed1e7;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row5_col2 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row5_col3 {
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row5_col4 {
#             background-color:  #a76c6c;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row5_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row6_col1 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row6_col2 {
#             background-color:  #fee7db;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row6_col3 {
#             background-color:  #c9eac2;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row6_col4 {
#             background-color:  #ae7171;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row6_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row7_col1 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row7_col2 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row7_col3 {
#             background-color:  #aedea7;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row7_col4 {
#             background-color:  #8a5858;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row7_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row8_col1 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row8_col2 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row8_col3 {
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row8_col4 {
#             background-color:  #845454;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row8_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row9_col1 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row9_col2 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row9_col3 {
#             background-color:  #d3eecd;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row9_col4 {
#             background-color:  #593737;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row9_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row10_col1 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row10_col2 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row10_col3 {
#             background-color:  #70c274;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row10_col4 {
#             background-color:  #3c2222;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row10_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row11_col1 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row11_col2 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row11_col3 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row11_col4 {
#             background-color:  #5e3a3a;
#             color:  #f1f1f1;
#         }    #T_ba82f28c_8f66_11ea_87e9_f82819259437row11_col5 {
#             background-color:  #000000;
#             color:  #f

# %%
spread = pd.read_csv('covid_19_india.csv')
spread['Date'] = pd.to_datetime(spread['Date'], dayfirst=True,)
india_spread = spread
india_spread['Active'] = india_spread['Confirmed'] - (india_spread['Deaths'] + india_spread['Cured'])
india_spread = india_spread.groupby('Date')['Confirmed','Deaths','Cured', 'Active'].sum().reset_index()
india_spread['Confirmed_diff'] = india_spread['Confirmed'].diff()
india_spread['Death_diff'] = india_spread['Deaths'].diff()
india_spread['Recovered_diff'] = india_spread['Cured'].diff()

# %%
datewise = india_spread.groupby('Date')['Confirmed','Deaths','Cured', 'Active'].sum().reset_index()

# %%
datewise.head(20)
# Out:
#          Date  Confirmed  Deaths  Cured  Active
# 0  2020-01-30          1       0      0       1
# 1  2020-01-31          1       0      0       1
# 2  2020-02-01          2       0      0       2
# 3  2020-02-02          3       0      0       3
# 4  2020-02-03          3       0      0       3
# 5  2020-02-04          3       0      0       3
# 6  2020-02-05          3       0      0       3
# 7  2020-02-06          3       0      0       3
# 8  2020-02-07          3       0      0       3
# 9  2020-02-08          3       0      0       3
# 10 2020-02-09          3       0      0       3
# 11 2020-02-10          3       0      0       3
# 12 2020-02-11          3       0      0       3
# 13 2020-02-12          3       0      0       3
# 14 2020-02-13          3       0      0       3
# 15 2020-02-14          3       0      0       3
# 16 2020-02-15          3       0      0       3
# 17 2020-02-16          3       0      0       3
# 18 2020-02-17          3       0      0       3
# 19 2020-02-18          3       0      0       3

# %% [markdown]
# # Arima Model

# %% [markdown]
# ARIMA stands for AutoRegressive (AR) Integrated (I) Moving Average (MA). The provided data as input must be an univariate series, since ARIMA calculates future datapoints from the past. That is exactly what we were trying to do with linear regression as well. ARIMA basically has three important parameters:
#
# p: The autoregressive part of the model. Simplified one can say that the model assumes that if there were many confirmed cases yesterday and the day before, there will be many confirmed cases today and tomorrow.
#
# d -> The integrated part of the model that describes the amount of differentiation. If the available data are not stationary and contain trends, ARIMA can extract this seasonality.
#
# q -> The moving average part of the model. By forming moving averages, random effects can be smoothed.

# %%
pyplot.figure(figsize=(10,5))
pyplot.plot(datewise["Confirmed"])
pyplot.plot(datewise["Deaths"])
pyplot.plot(datewise["Cured"])

pyplot.legend()
pyplot.xlabel("Date")
pyplot.ylabel("Number of Death Cases")
pyplot.xticks(rotation=90)
# Out:
# No handles with labels found to put in legend.
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
confirmedcases = datewise['Confirmed'].to_list()
confirmedcases
# Out:
# [1,
#  1,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  5,
#  6,
#  28,
#  30,
#  31,
#  34,
#  39,
#  46,
#  58,
#  60,
#  74,
#  81,
#  84,
#  110,
#  114,
#  137,
#  151,
#  173,
#  223,
#  283,
#  360,
#  433,
#  519,
#  606,
#  694,
#  724,
#  909,
#  1024,
#  1251,
#  1397,
#  1834,
#  2069,
#  2547,
#  3072,
#  3577,
#  4281,
#  4789,
#  5274,
#  5865,
#  6761,
#  7529,
#  8447,
#  9352,
#  10815,
#  11933,
#  12759,
#  13835,
#  14792,
#  16116,
#  17656,
#  18985]

# %%
plotconf = datewise['Confirmed']

# %%
plot_acf(plotconf)
pyplot.show()

# %%
plot_pacf(plotconf)
pyplot.show()

# %%
model_arima=ARIMA(confirmedcases,(1,1,0))
model_arima_fit=model_arima.fit()
prediction_arima=model_arima_fit.forecast(7)[0]
prediction_arima
# Out:
# array([20289.33554161, 21569.68529558, 22826.70925824, 24061.04926539,
#        25273.32949197, 26464.15693804, 27634.12190135])

# %%
plotingconfirmed = datewise.copy()
del plotingconfirmed['Deaths']
del plotingconfirmed['Cured']
del plotingconfirmed['Active']

# %%
oneweekdates = ['2020-4-22','2020-4-23','2020-4-24','2020-4-25','2020-4-26','2020-4-27','2020-4-28']

# %%
plotingconfirmed.tail()
# Out:
#          Date  Confirmed
# 78 2020-04-17      13835
# 79 2020-04-18      14792
# 80 2020-04-19      16116
# 81 2020-04-20      17656
# 82 2020-04-21      18985

# %%
j=1
for i in range(len(oneweekdates)):
    plotingconfirmed.loc[82+j,'Date'] = oneweekdates[i]
    plotingconfirmed.loc[82+j,'Confirmed'] =int(prediction_arima[i])
    j=j+1

# %%
plotingconfirmed['Date'] = pd.to_datetime(plotingconfirmed['Date'])

# %%
plotingconfirmed.tail(20)
# Out:
#          Date  Confirmed
# 70 2020-04-09     5865.0
# 71 2020-04-10     6761.0
# 72 2020-04-11     7529.0
# 73 2020-04-12     8447.0
# 74 2020-04-13     9352.0
# 75 2020-04-14    10815.0
# 76 2020-04-15    11933.0
# 77 2020-04-16    12759.0
# 78 2020-04-17    13835.0
# 79 2020-04-18    14792.0
# 80 2020-04-19    16116.0
# 81 2020-04-20    17656.0
# 82 2020-04-21    18985.0
# 83 2020-04-22    20289.0
# 84 2020-04-23    21569.0
# 85 2020-04-24    22826.0
# 86 2020-04-25    24061.0
# 87 2020-04-26    25273.0
# 88 2020-04-27    26464.0
# 89 2020-04-28    27634.0

# %%
arimapredictions = plotingconfirmed.copy()

# %%
arimapredictions.to_csv('Arima_predictions.csv')

# %%
pyplot.figure(figsize=(10,5))
pyplot.plot(plotingconfirmed["Confirmed"],label="ARIMA Prediction Set",marker="^")
pyplot.plot(datewise["Confirmed"],label="Confirmed Till Date",marker="o")
pyplot.legend()
pyplot.xlabel("Date")
pyplot.ylabel("Number of Death Cases")
pyplot.xticks(rotation=90)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100.]),
#  <a list of 7 Text major ticklabel objects>)
